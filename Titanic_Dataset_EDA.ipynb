# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil07-source/Exploratory-Data-Analysis_EDA/blob/main/Titanic_Dataset_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1. Problem Statement

# %% [markdown]
# The notebooks explores the basic use of __Pandas__ and will cover the basic commands of __Exploratory Data Analysis(EDA)__ which includes __cleaning__, __munging__, __combining__, __reshaping__, __slicing__, __dicing__, and __transforming data__ for analysis purpose.
# it involves collecting, aggregating, cleaning, and organizing the data to be consumed by the algorithms designed to make discoveries or to create models.
#
# * __Exploratory Data Analysis__ <br/>
# Understand the data by EDA and derive simple models with Pandas as baseline.
# EDA ia a critical and first step in analyzing the data and we do this for below reasons :
#     - Finding patterns in Data
#     - Determining relationships in Data
#     - Checking of assumptions
#     - Preliminary selection of appropriate models
#     - Detection of mistakes

# %% [markdown]
# ### 2. Data Loading and Description
# ![image.png](https://miro.medium.com/v2/resize:fit:720/format:webp/0*awbekd-RK9TrISOn)

# %% [markdown]
# - The dataset consists of the information about people boarding the famous RMS Titanic. Various variables present in the dataset includes data of age, sex, fare, ticket etc.
# - The dataset comprises of __891 observations of 12 columns__. Below is a table showing names of all the columns and their description.

# %% [markdown]
# | Column Name   | Description                                               |
# | ------------- |:-------------                                            :|
# | PassengerId   | Passenger Identity                                        |
# | Survived      | Whether passenger survived or not                         |
# | Pclass        | Class of ticket                                           |
# | Name          | Name of passenger                                         |
# | Sex           | Sex of passenger                                          |
# | Age           | Age of passenger                                          |
# | SibSp         | Number of sibling and/or spouse travelling with passenger |
# | Parch         | Number of parent and/or children travelling with passenger|
# | Ticket        | Ticket number                                             |
# | Fare          | Price of ticket                                           |
# | Cabin         | Cabin number                                              |

# %% [markdown]
# #### Some Background Information
# The sinking of the RMS Titanic in the early morning of __15 April 1912, four days into the ship's maiden voyage__ from __Southampton to New York City__, was one of the deadliest peacetime maritime disasters in history, __killing more
# than 1,500 people__. The largest passenger liner in service at the time, Titanic had an __estimated 2,224 people on
# board__ when she struck an __iceberg in the North Atlantic__. The ship had received __six warnings__ of sea ice but
# was travelling at near __maximum speed when the lookouts sighted the iceberg__. Unable to turn quickly enough, the
# ship suffered a glancing blow that buckled the starboard (right) side and opened __five of sixteen compartments to
# the sea__. The disaster caused widespread outrage over the lack of lifeboats, lax regulations, and the __unequal treatment__ of the three passenger classes during the evacuation. Inquiries recommended sweeping changes to maritime regulations, leading to the __International Convention for the Safety of Life at Sea (1914)__, which continues to govern maritime safety.

# %% [markdown]
# #### Importing packages

# %%
#Getting Pandas Profiling Report
# !pip install https://github.com/ydataai/pandas-profiling/archive/master.zip
# Out:
# ...
#      - 17.9 MB 27.9 MB/s 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 63.6 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=390592 sha256=0b0a145c6f3766fd161a04d0a01b9fa8861421c0f4e045ec7c52ed2745bca759
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ttnlu03i/wheels/f5/4e/04/09011c49d76834ce963a4fe57acc90b11fa8bb282bb9781d97
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=8cec507ca2c3d338f49ad9c63e2eca03696b0c0e952831ad7358c448593df62c
# ...

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport  #importing pandas preprofiling

import numpy as np                         #importing numpy library
import pandas as pd                        #importing pandas library
import matplotlib.pyplot as plt            #importing matplotlib library
import seaborn as sns                      #importing seaborn library
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Nikhil07-source/Exploratory-Data-Analysis_EDA/refs/heads/main/Titanic-Dataset.csv")
df                                  #getting dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)            #Getting the type of the Dataset.
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()           #here we are getting a short information using info() function.
#Following are the things we came to know by using info() function.
#1. There are total 891 enteries, starting form index 0-890.
#2. There are total 12 columns.
#3. Columns names are -  PassengerId,Survived,Pclass,Name,Sex,Age,Sibsp,Parch,Ticket,Fare,Cabin & Embarked.
#4. There are no null values in any columns except - Age,Cabin & Embarked.
#5. Datatype of the columns.
#6. Memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#finding datatype of particular data
data_type = df.Name[1]        #getting 1st index of 'Name' column and storing it into new variable name - 'data_type'
type(data_type)               #getting the datatype variable 'data_type' which is defined above.
# Out:
# str

# %% [markdown]
# ## 3. Data Profiling

# %% [markdown]
# - In the upcoming sections we will first __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %% [markdown]
# ### 3.1 Understanding the Dataset

# %% [markdown]
# To gain insights from data we must look into each aspect of it very carefully. We will start with observing few rows and columns of data both from the starting and from the end

# %%
df.shape      #getting the shape of the dataframe=df, which shows (891*12) which means 891 rows, 12 columns.
# Out:
# (891, 12)

# %%
df.columns    #getting all columns.
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(10)   #getting all data from top 10 rows including index 0.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)   #getting all data from last 10 rows.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.isnull()     #checking null values in each rows & columns using isnull() function, True = null values, False = no null values.
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()       #getting total number of null values in every columns using sum() function.
#column 'Age' is having 177 null values.
#column 'Cabin' is having 687 null values.
#column 'Embarked' is having 2 null values.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# From the above output we can see that __Age__ and __Cabin__ columns contains __maximum null values__. We will see how to deal with them.

# %% [markdown]
# ### 3.2 Pre Profiling

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %%
profile = ProfileReport(df, title="Titanic Dataset Profile")

# %% [markdown]
# - __ProfileReport__: This is the main function from the pandas_profiling library that generates the report.
# - __df__: This is the DataFrame containing the Titanic dataset that we want to analyze.
# - __title__: This parameter allows us to set a custom title for the report, which in this case is "Titanic Dataset Profile".

# %%
 profile.to_file(output_file="titanic_before_processing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# - __profile__: This is an instance of the ProfileReport class created from a pandas DataFrame.
# - __to_file()__: This method is used to write the profiling report to a specified output file.
# - __output_file__: This parameter specifies the name of the file where the report will be saved.</br></br>
#
# Here, we have done Pandas Profiling before preprocessing our dataset, so we have named the html file as __titanic_before_preprocessing.html__. </br></br>Take a look at the file and see what useful insight you can develop from it.</br></br>
# Now we will process our data to better understand it.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for name in df.Name:      #using for loop to get all the names in dataframe=df.
  print(name)
# Out:
# Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry
# Moran, Mr. James
# McCarthy, Mr. Timothy J
# Palsson, Master. Gosta Leonard
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser, Mrs. Nicholas (Adele Achem)
# Sandstrom, Miss. Marguerite Rut
# Bonnell, Miss. Elizabeth
# Saundercock, Mr. William Henry
# Andersson, Mr. Anders Johan
# Vestrom, Miss. Hulda Amanda Adolfina
# Hewlett, Mrs. (Mary D Kingcome)
# Rice, Master. Eugene
# Williams, Mr. Charles Eugene
# Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# Masselmani, Mrs. Fatima
# Fynney, Mr. Joseph J
# Beesley, Mr. Lawrence
# McGowan, Miss. Anna "Annie"
# Sloper, Mr. William Thompson
# Palsson, Miss. Torborg Danira
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# Emir, Mr. Farred Chehab
# Fortune, Mr. Charles Alexander
# O'Dwyer, Miss. Ellen "Nellie"
# Todoroff, Mr. Lalio
# ...

# %% [markdown]
# ### 3.3 Preprocessing

# %% [markdown]
# - Dealing with missing values<br/>
#     - Dropping/Replacing missing entries of __Embarked.__
#     - Replacing missing values of __Age__ with median values.
#     - Dropping the column __'Cabin'__ as it has too many _null_ values.
#     - Replacing 0 values of fare with median values.

# %%
df['Embarked'].value_counts()       #counting the total values of column 'Embarked'.
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df[df['Embarked'].isnull()]   #getting rows in which 'Embarked' values are null.
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df['Embarked'].mode()   #getting the mode of column 'Embarked', mode = highest frequency occured.
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
embarked_mode = df['Embarked'].mode()[0]    #getting the mode value of 'Embarked' column and storing it to 'embarked_mode' variable.

# %%
df['Embarked'].isnull().sum()  #there are 2 null values in 'Embarked' column. Now we are going to replace it with mode of column 'Embarked'.
# Out:
# 2

# %%
df['Embarked'].fillna(embarked_mode, inplace=True) #filling null values in 'Embarked' column with mode of column 'Embarked'.
# Out:
# <ipython-input-23-5afb45fc3539>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(embarked_mode, inplace=True) #filling null values in 'Embarked' column with mode of column 'Embarked'.

# %%
df['Embarked'].isnull().sum()   #now there are no null values in column 'Embarked'.
# Out:
# 0

# %% [markdown]
# ###__Dropping a row having missing values__
#     titanic_data.Embarked.dropna(inline=True)
# This code can remove missing values in 'Embarked' column but remember, it will remove whole row. Maybe there are other essential things in other columns in same row, thatwhy we did not prefer directly dropping first. It is the last option.

# %% [markdown]
# ###__Dealing with the Null values in age column__

# %%
#Getting the median age of the passenger who did not survived
df['Age'].median()
#df.Age.median()
# Out:
# 28.0

# %%
#Getting Percentage of passengers survived.

total_rows = df['Survived'].count()                                             #getting total number of passenger
total_survived = df[df['Survived']==1]['Survived'].count()                      #getting number of passenger survived
percentage = (total_survived/total_rows) * 100                                  #calculating percentage = (342/891)*100

print('Total number of passenger: ', total_rows)
print('Total numbers of passenger survived: ', total_survived)
print('Percentage of passengers survived: ', percentage)
# Out:
# Total number of passenger:  891
# Total numbers of passenger survived:  342
# Percentage of passengers survived:  38.38383838383838

# %%
#Filling the missing values in 'Age' with Median Value of Age.

median_age = df['Age'].median()                         #getting median of age column
df['Age'].fillna(median_age, inplace=True)              #replacing null rows under age column by median of age
df['Age'].info()                                       #getting the information of age column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# <ipython-input-27-d4044320bdbf>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(median_age, inplace=True)              #replacing null rows under age column by median of age

# %%
#Dropping the Cabin column as the no. of data rows are very low and is not supposed to contribute much to the Analysis.
df.drop('Cabin', axis=1, inplace=True) #Dropping cabin column, axis=0 is for row, axis=1 is for column
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Embarked
# 0      0  A/5 21171  7.25        S

# %%
#Dropping ticket & passengerid, as these columns are not much required.
df.drop('Ticket', axis=1, inplace=True)
df.drop('PassengerId', axis=1, inplace=True)
df.head(1)
# Out:
#    Survived  Pclass                     Name   Sex   Age  SibSp  Parch  Fare  \
# 0         0       3  Braund, Mr. Owen Harris  male  22.0      1      0  7.25
#
#   Embarked
# 0        S

# %% [markdown]
# ####Checking the age of passengers with 0 Fare.

# %%
#Getting the count of rows where fare is 0.
print('Total number of passengers whose fare is 0: ',df[df['Fare']==0]['Fare'].count()  )    #15 passengers whose fare is 0.
df[df.Fare==0]  #Getting the rows whose fare is 0.0.
# Out:
# Total number of passengers whose fare is 0:  15
#      Survived  Pclass                              Name   Sex   Age  SibSp  \
# 179         0       3               Leonard, Mr. Lionel  male  36.0      0
# 263         0       1             Harrison, Mr. William  male  40.0      0
# 271         1       3      Tornquist, Mr. William Henry  male  25.0      0
# 277         0       2       Parkes, Mr. Francis "Frank"  male  28.0      0
# 302         0       3   Johnson, Mr. William Cahoone Jr  male  19.0      0
# 413         0       2    Cunningham, Mr. Alfred Fleming  male  28.0      0
# 466         0       2             Campbell, Mr. William  male  28.0      0
# 481         0       2  Frost, Mr. Anthony Wood "Archie"  male  28.0      0
# 597         0       3               Johnson, Mr. Alfred  male  49.0      0
# 633         0       1     Parr, Mr. William Henry Marsh  male  28.0      0
# 674         0       2        Watson, Mr. Ennis Hastings  male  28.0      0
# ...

# %%
#Checking the age of passengers with 0 Fare.
df[df.Fare==0].Age  #getting the age whose fare is 0.0.
# Out:
# 179    36.0
# 263    40.0
# 271    25.0
# 277    28.0
# 302    19.0
# 413    28.0
# 466    28.0
# 481    28.0
# 597    49.0
# 633    28.0
# 674    28.0
# 732    28.0
# 806    39.0
# 815    28.0
# 822    38.0
# Name: Age, dtype: float64

# %%
#Checking the median value of the fare.
df['Fare'].median()
# Out:
# 14.4542

# %%
#Replace the 0 value of Fare with median Value. Cansidering that 0 value of fare was input by mistake.
df['Fare'].replace(0, df['Fare'].median(), inplace=True) #replacing row in which fare is 0, with median of the fare.
df[df.Fare == 0].Age #checking if fare 0 still exists.
# Out:
# <ipython-input-34-f1d3d360179c>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].replace(0, df['Fare'].median(), inplace=True) #replacing row in which fare is 0, with median of the fare.
# Series([], Name: Age, dtype: float64)

# %%
print('The mean of the fare is: ', df['Fare'].mean())
print('The median of the fare is: ', df['Fare'].median())
df.groupby('Pclass')['Fare'].mean() #getting the mean of fare according to pclass.
# Out:
# The mean of the fare is:  32.44754466891134
# The median of the fare is:  14.4542
# Pclass
# 1    84.489275
# 2    21.133516
# 3    13.793303
# Name: Fare, dtype: float64

# %%
#Creating a new column called GenderClass in which passenger under or equals to 15 age will considerd as child, else there will be male or female for adult.
df['GenderClass'] = df.apply(lambda x: 'child' if x['Age']< 15 else x['Sex'], axis=1)
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Embarked GenderClass
# 0    male  22.0      1      0   7.2500        S        male
# 1  female  38.0      1      0  71.2833        C      female
# ...

# %%
#Create a new Column : Family Size in which consist 'Siblings & Spouse' & 'Parents & Childrens' and +1 means themselves.
df['FamilySize'] = df['SibSp'] + df['Parch']+1
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch     Fare Embarked GenderClass  FamilySize
# 0    male  22.0      1      0   7.2500        S        male           2
# ...

# %%
#Creating countplot using seaborn
sns.countplot(x='FamilySize', data = df)    #Creating countplot using seaborn, where x = 'FamilySize' column and data is from dataframe = df.
plt.show()                                  #showing plot

# %% [markdown]
# __Observation__: Most of the Passangers travelled solo.

# %%
#Dropping sex column as we create Gender Class column for that.
df.drop('Sex', axis=1, inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                            Braund, Mr. Owen Harris  22.0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2         1       3                             Heikkinen, Miss. Laina  26.0
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4         0       3                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch     Fare Embarked GenderClass  FamilySize
# 0      1      0   7.2500        S        male           2
# 1      1      0  71.2833        C      female           2
# 2      0      0   7.9250        S      female           1
# 3      1      0  53.1000        S      female           2
# 4      0      0   8.0500        S        male           1

# %%
#Dropping name column as it is not needed.
df.drop('Name', axis=1, inplace=True)
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked GenderClass  \
# 0         0       3  22.0      1      0   7.2500        S        male
# 1         1       1  38.0      1      0  71.2833        C      female
# 2         1       3  26.0      0      0   7.9250        S      female
# 3         1       1  35.0      1      0  53.1000        S      female
# 4         0       3  35.0      0      0   8.0500        S        male
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
#Dropping the Duplicate values originated as result of Pandas Preprocessing.
df.drop_duplicates(inplace=True)
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked GenderClass  \
# 0         0       3  22.0      1      0   7.2500        S        male
# 1         1       1  38.0      1      0  71.2833        C      female
# 2         1       3  26.0      0      0   7.9250        S      female
# 3         1       1  35.0      1      0  53.1000        S      female
# 4         0       3  35.0      0      0   8.0500        S        male
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
#checking data is good to go ahead or not.
df.count()
# Out:
# Survived       774
# Pclass         774
# Age            774
# SibSp          774
# Parch          774
# Fare           774
# Embarked       774
# GenderClass    774
# FamilySize     774
# dtype: int64

# %% [markdown]
# ## 3.4 Post Pandas Profiling

# %%
#import pandas_profiling
profile = ProfileReport(df)
#profile.to_notebook_iframe()
profile.to_file("Titanic_after_preprocessing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Now we have preprocessed the data, now the dataset doesnot contain missing values, we have also introduced new feature named __FamilySize__. So, the pandas profiling report which we have generated after preprocessing will give us more beneficial insights. You can compare the two reports, i.e __titanic_after_preprocessing.html__ and titanic_before_preprocessing.html.<br/>
# In titanic_after_preprocessing.html report, observations:
# - In the Dataset info, Total __Missing(%)__ = __0.0%__
# - Number of __variables__ = __13__
# - Observe the newly created variable FamilySize, Click on Toggle details to get more detailed information about it.

# %% [markdown]
# #### 4.1 Of all the passengers, how many survived and how many died ?

# %%
sns.countplot(x='Survived', data=df).set_title('Count plot for Number of passengers Died and Survived')
plt.show()

survive = df[df['Survived']==1]['Survived'].count() #getting the count of numbers of passengers who survive and then storing it in survive variable.
died = df[df['Survived']==0]['Survived'].count()    #getting the count of numbers of passengers who died and then storing it in died variable.

print('No of passengers died: ', died)
print('No of passengers survived: ', survive)
# Out:
# No of passengers died:  455
# No of passengers survived:  319

# %% [markdown]
# You can see that __more people died than survived.__ To know the exact count:

# %%
df.groupby('Survived')['Survived'].count()
# Out:
# Survived
# 0    455
# 1    319
# Name: Survived, dtype: int64

# %% [markdown]
# Notice that __455__ people __died__ and only __319 survived.__

# %% [markdown]
# #### 4.2 Who is more likely to survive, Male or Female?

# %%
as_fig=sns.FacetGrid(df,hue='GenderClass', aspect=4)
as_fig.map(sns.kdeplot,'Age', shade=True)
oldest = df['Age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()
plt.title('Age Distribution using FacetGrid')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# Text(0.5, 1.0, 'Age Distribution using FacetGrid')

# %% [markdown]
# - In titanic RMS __child__ of Age __3-8__ yrs are in majority.
# - Maximum __males and females__ are of Age __25-35__ yrs.

# %% [markdown]
# ###Using groupby

# %%
#Creating group using grouby() function by 'Survived','GenderClass','Pclass' column.
df.groupby(['Survived','GenderClass','Pclass'])['Survived'].count()
# Out:
# Survived  GenderClass  Pclass
# 0         child        1           1
#                        3          32
#           female       1           2
#                        2           6
#                        3          53
#           male         1          74
#                        2          75
#                        3         212
# 1         child        1           4
#                        2          18
#                        3          21
#           female       1          89
#                        2          56
#                        3          48
#           male         1          40
#                        2           8
#                        3          35
# Name: Survived, dtype: int64

# %%
#Getting total number of passengers survived
female_survive = df[df.GenderClass == 'female'][df.Survived == 1]['Survived'].count()
male_survive = df[df.GenderClass == 'male'][df.Survived == 1]['Survived'].count()
kids_survive = df[df.GenderClass == 'child'][df.Survived == 1]['Survived'].count()

print('Total number of females survived are: ', female_survive)
print('Total number of males survived are: ', male_survive)
print('Total number of child survived are: ', kids_survive)
# Out:
# Total number of females survived are:  193
# Total number of males survived are:  83
# Total number of child survived are:  43
# <ipython-input-48-2958ca9fd67c>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   female_survive = df[df.GenderClass == 'female'][df.Survived == 1]['Survived'].count()
# <ipython-input-48-2958ca9fd67c>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   male_survive = df[df.GenderClass == 'male'][df.Survived == 1]['Survived'].count()
# <ipython-input-48-2958ca9fd67c>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   kids_survive = df[df.GenderClass == 'child'][df.Survived == 1]['Survived'].count()

# %% [markdown]
# - Majority of __males died__.
# - __Females__ have high probability to __survive.__

# %% [markdown]
# To know the exact %

# %%
total_pessenger_survive = df[df.Survived == 1]['Survived'].count()  #getting total number of passengers survived

female_percentage = (female_survive/total_pessenger_survive) * 100
male_percentage = (male_survive/total_pessenger_survive) * 100
kids_percentage = (kids_survive/total_pessenger_survive) * 100

print(female_percentage, '% womens survived')
print(male_percentage, '% mens survived')
print(kids_percentage, '% childrens survived')
# Out:
# 60.50156739811913 % womens survived
# 26.01880877742947 % mens survived
# 13.479623824451412 % childrens survived

# %%
f,ax = plt.subplots(1,3,figsize=(15,7))
df['Survived'][df['GenderClass']=='male'].value_counts().plot.pie(explode=[0,0.2], autopct='%1.1f%%', ax=ax[0], shadow=True)
df['Survived'][df['GenderClass']=='female'].value_counts().plot.pie(explode=[0,0.2], autopct='%1.1f%%', ax=ax[1], shadow=True)
df['Survived'][df['GenderClass']=='child'].value_counts().plot.pie(explode=[0,0.2], autopct='%1.1f%%', ax=ax[2], shadow=True)
ax[0].set_title('Survived (male)')
ax[1].set_title('Survived (female)')
ax[2].set_title('Survived (child)')
# Out:
# Text(0.5, 1.0, 'Survived (child)')

# %%
data = [int(female_survive),int(male_survive),int(kids_survive)]
labels = ['Survived (females)', 'Survived (male)', 'Survived (child)']

# Set Seaborn style
sns.set_style("whitegrid")

# Create pie chart
plt.pie(data, labels=labels, autopct='%1.1f%%')
plt.title("Survived passenger according 'GenderClass'")
plt.show()

# %% [markdown]
# From the above pie plot you can see how survival depends on whether the passenger is a child, male or female.
# - __60.5% of females__ survived.
# - __13.5% of children__ also survived.
# - Only __26% of males__ survived.

# %%
#count of males by column 'GenderClass'
df['Survived'][df['GenderClass']=='male'].value_counts()
# Out:
# Survived
# 0    361
# 1     83
# Name: count, dtype: int64

# %%
#count of females by column 'GenderClass'
df['Survived'][df['GenderClass']=='female'].value_counts()
# Out:
# Survived
# 1    193
# 0     61
# Name: count, dtype: int64

# %% [markdown]
# ### 4.4. What is the rate of survival of males, females and child on the basis of Passenger Class?

# %%
df.head(1)
# Out:
#    Survived  Pclass   Age  SibSp  Parch  Fare Embarked GenderClass  FamilySize
# 0         0       3  22.0      1      0  7.25        S        male           2

# %%
pclass1 = df[df.Pclass == 1][df.Survived == 1]['Survived'].count()
pclass2 = df[df.Pclass == 2][df.Survived == 1]['Survived'].count()
pclass3 = df[df.Pclass == 3][df.Survived == 1]['Survived'].count()
survived = df[df.Survived == 1]['Survived'].count()
#Printing values
print('Number of passenger survived in class 1: ', pclass1)
print('Number of passenger survived in class 2: ', pclass2)
print('Number of passenger survived in class 3: ', pclass3)
print('Total number of passenger survived: ', survived)
#Calculating Percentage
print('\n')
print((pclass1/survived) * 100, '% of passenger survived in Class 1')
print((pclass2/survived) * 100, '% of passenger survived in Class 2')
print((pclass3/survived) * 100, '% of passenger survived in Class 3 \n\n')
# Out:
# Number of passenger survived in class 1:  133
# Number of passenger survived in class 2:  82
# Number of passenger survived in class 3:  104
# Total number of passenger survived:  319
#
#
# 41.692789968652036 % of passenger survived in Class 1
# 25.705329153605017 % of passenger survived in Class 2
# 32.60188087774294 % of passenger survived in Class 3
# <ipython-input-55-f943bed7e733>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pclass1 = df[df.Pclass == 1][df.Survived == 1]['Survived'].count()
# <ipython-input-55-f943bed7e733>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pclass2 = df[df.Pclass == 2][df.Survived == 1]['Survived'].count()
# <ipython-input-55-f943bed7e733>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pclass3 = df[df.Pclass == 3][df.Survived == 1]['Survived'].count()

# %% [markdown]
# - Using crosstab function

# %%
pd.crosstab([df.GenderClass, df.Survived], df.Pclass, margins=True).apply(lambda r: 100*r/len(df), axis=1).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_bc7bb_row0_col0, #T_bc7bb_row0_col1, #T_bc7bb_row0_col3, #T_bc7bb_row1_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_bc7bb_row0_col2 {
#   background-color: #fff800;
#   color: #000000;
# }
# #T_bc7bb_row1_col0, #T_bc7bb_row1_col3 {
#   background-color: #fffc00;
#   color: #000000;
# }
# #T_bc7bb_row1_col1 {
#   background-color: #ffe300;
#   color: #000000;
# }
# #T_bc7bb_row2_col0 {
#   background-color: #fffe00;
#   color: #000000;
# }
# #T_bc7bb_row2_col1, #T_bc7bb_row2_col3, #T_bc7bb_row5_col2 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_bc7bb_row2_col2 {
#   background-color: #ffea00;
#   color: #000000;
# }
# #T_bc7bb_row3_col0 {
#   background-color: #ff9400;
#   color: #000000;
# }
# #T_bc7bb_row3_col1 {
#   background-color: #ffa800;
#   color: #000000;
# }
# #T_bc7bb_row3_col2 {
#   background-color: #ffed00;
#   color: #000000;
# }
# #T_bc7bb_row3_col3 {
#   background-color: #ffc800;
#   color: #000000;
# ...

# %%
df.groupby(['Survived','GenderClass','Pclass'])['Survived'].count()
# Out:
# Survived  GenderClass  Pclass
# 0         child        1           1
#                        3          32
#           female       1           2
#                        2           6
#                        3          53
#           male         1          74
#                        2          75
#                        3         212
# 1         child        1           4
#                        2          18
#                        3          21
#           female       1          89
#                        2          56
#                        3          48
#           male         1          40
#                        2           8
#                        3          35
# Name: Survived, dtype: int64

# %% [markdown]
# You can see how the percentage of males, females and children survived are varying depending on the passenger class they are in. Also, its quiet difficult to develop quick insights by looking only at numbers. Therefore we will explore doing the same with the help of __plotting.__

# %% [markdown]
# - Using __violin plot__ to see the relationship between __Pclass and Survived__

# %%
sns.violinplot(x="Pclass", y="Survived", data=df, palette="muted")
plt.title('Vioninplot Pclass vs Survived')
plt.show()
# Out:
# <ipython-input-58-4fbbac454422>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Pclass", y="Survived", data=df, palette="muted")

# %% [markdown]
# Above is another beautiful way to see how the survival rate is varying with Passenger class.
# - __Pclass 3__ have __more__ people who __died__, and for __Pclass 1 survival rate is more.__

# %% [markdown]
#  Drawing __countplot__ to look at the __distribution of popluation__ with __Pclass and GenderClass.__

# %%
sns.catplot(data=df, hue='GenderClass', x = 'Pclass', kind='count')
plt.title('Factorplot with kind= "Count" for Pclass and GenderClass')
plt.show()

# %% [markdown]
# 1. __Pclass 3__ have _maximum_ number of __males__
# 2. __Pclass 1__ have _minimum_ number of __children__.

# %% [markdown]
# - using factorplot to see the variation of __survival rate with Pclass and GenderClass.__

# %%
sns.catplot(data=df, x='Survived', y='Pclass', hue='GenderClass')
plt.title('Factorplot for Survival rate variation with Pclass and GenderClass')
plt.show()

# %% [markdown]
# The above graph shows:
# 1. the survival rate for male is very __low__ _irrespective of the class_ he belongs to.
# 2. And, the survival rate is _less_ for all the _3rd class passengers._
# 3. __Almost all women__ in Pclass __1 and 2 survived__ and __nearly all men__ in Pclass __2 and 3 died.__

# %% [markdown]
# ### 4.4 What is the survival rate considering the Embarked variable?

# %% [markdown]
# - Using countplot

# %%
sns.countplot(data=df, hue='Survived', x='Embarked')
plt.title('Survival rate considering the Embarked variable')
plt.show()

# %%
## 6% of the females survived from the overall data set and who embarked at C and were females.
100*df.groupby(['Embarked','GenderClass'])['Survived'].value_counts()/len(df)
# Out:
# Embarked  GenderClass  Survived
# C         child        1            1.421189
#                        0            0.387597
#           female       1            6.976744
#                        0            0.904393
#           male         0            7.105943
#                        1            3.229974
# Q         child        0            0.516796
#           female       1            2.196382
#                        0            1.162791
#           male         0            3.229974
#                        1            0.387597
# S         child        1            4.134367
#                        0            3.359173
#           female       1           15.762274
#                        0            5.813953
#           male         0           36.304910
#                        1            7.105943
# Name: count, dtype: float64

# %% [markdown]
# 1. __Maximum___ number of people have __Southampton__ as port of embarkment.
# 2. Also observe people who boarded at _Cherbourg_, _more_ people _survived than died_, and this is reverse for Queenstown.

# %% [markdown]
# - Using __factorplot__ and __kind = 'point'__

# %%
sns.catplot(data=df, x='Embarked', y='Survived', kind='point')
plt.title('Factorplot for Embarked and Survived')
plt.show()

# %% [markdown]
# ### 4.5. Survival rate - Comparing Embarked and Sex.

# %% [markdown]
# - Distribution of _GenderClass_ with respect to _Port of Embarkment_ using __Countplot__.

# %%
sns.countplot(data=df, x='Embarked', hue='GenderClass')
plt.title('Distribution of GenderClass with respect to Port of Embarkment')
plt.show()

# %% [markdown]
# Most of the people boarded from __S__, Also among all who boarded, __males__ constitutes the __majority__ of percentage.
#
# - Using Factorplot to see variation of __survival rate with port of embarkment and GenderClass__

# %%
sns.catplot(data=df, y='Survived', x='Embarked', hue='GenderClass', kind='point')
plt.title('Variation of survival rate with port of embarkment and GenderClass')
plt.show()

# %% [markdown]
# - Chances of survival of __females__ who boarded from __C__ is _highest_.
# - Chances of survival of __males__ boarding from __Q__ is _lowest_

# %% [markdown]
# ### 4.6 How survival rate vary with Embarked, Sex and Pclass.

# %% [markdown]
# Seeing relation between Pclass and Embarked.

# %%
relation = pd.crosstab(df.Embarked, df.Pclass)
relation.plot.barh(figsize=(15,5))
plt.xticks(size=10)
plt.yticks(size=10)
plt.title('Relation between Pclass and Embarked', size=15)
# Out:
# Text(0.5, 1.0, 'Relation between Pclass and Embarked')

# %% [markdown]
# Maximum people who boarded from __S__ belongs to __Pclass 3__.<br/>
# Most of the passengers belonging to __Pclass 1__ boarded from __C and S__

# %% [markdown]
# - Using Swarmplot

# %%
sns.set(style='whitegrid', palette='muted')
sns.swarmplot(x='Embarked', y='Age', hue='GenderClass', data=df, palette='gnuplot')
plt.title('Using Swarmplot for getting Embarked, Age & GenderClass')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 28.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.set(style='whitegrid', palette='muted')
sns.swarmplot(x='Survived', y='Age', hue='Pclass', palette='gnuplot', data=df)
plt.title('Using Swarmplot for getting Survived, Age & Pclass')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 16.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# - Using factorplot with kind = 'point'

# %%
sns.catplot(data=df, x='Embarked', y='Survived', hue='GenderClass', kind='point', col='Pclass')
plt.show()

# %% [markdown]
# - Practically all _women_ of __Pclass 2__ that embarked in __C and Q survived__, also nearly all _women_ of __Pclass 1__ survived_.
# - All _men_ of __Pclass 1 and 2__ embarked in __Q died__, survival rate for men in __Pclass 2 and 3__ is always __below 0.2__.
# - For the remaining men in Pclass 1 that embarked in S and C, survival rate is approx. __0.4__

# %% [markdown]
# ### 4.7 Segment age in bins with size 10.

# %%
#creating category like 0-10,11-20,21-30,31-40,41-50..... and storing values to a new column called 'Age_Bin'.
for i in range (8,0,-1):
  df.loc[df['Age']<=i*10, 'Age_Bin']=i

df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked GenderClass  \
# 0         0       3  22.0      1      0   7.2500        S        male
# 1         1       1  38.0      1      0  71.2833        C      female
# 2         1       3  26.0      0      0   7.9250        S      female
# 3         1       1  35.0      1      0  53.1000        S      female
# 4         0       3  35.0      0      0   8.0500        S        male
#
#    FamilySize  Age_Bin
# 0           2      3.0
# 1           2      4.0
# 2           1      3.0
# 3           2      4.0
# 4           1      4.0

# %%
df.plot.hexbin(x='Age_Bin', y='Survived', gridsize=12, legend=True)
plt.title('Survived passenger according to Age_Bin')
plt.show()

# %% [markdown]
# Comparing count of those who survived and died with respect to the Age_bin they are in.
# - __Age_bin 1__: As you can see hexagon for Survived( 1.0 ) is darker than Died(0.0), means __more children survived than died__.
# - __Age_bin 3__: __More died than survived__, Also count of survived is highest among all age bins ( see horizontaly along Survived = 1.0 ) , means maximum people who boarded Titanic were from this age group.
# - __Age_bin >4__: More people died than survived.

# %%
sns.barplot(x='Age_Bin',y='Survived', hue='Pclass', data=df)
plt.title('Survived passenger according to Age_Bin')
plt.show()

# %%
# From age Bin 8 > There are 3 passengers in pclass=1 ( 1 survived, 2 died), none in pclasss=2, 2 in pclass =3, both died.
df.groupby(['Pclass','Survived','Age_Bin'])['Age_Bin'].count()
# Out:
# Pclass  Survived  Age_Bin
# 1       0         1.0          1
#                   2.0          3
#                   3.0         25
#                   4.0         12
#                   5.0         16
#                   6.0         10
#                   7.0          8
#                   8.0          2
#         1         1.0          2
#                   2.0         15
#                   3.0         40
#                   4.0         37
#                   5.0         21
#                   6.0         15
#                   7.0          2
#                   8.0          1
# 2       0         2.0          8
#                   3.0         31
#                   4.0         21
#                   5.0          9
#                   6.0         10
#                   7.0          2
#         1         1.0         16
#                   2.0          9
#                   3.0         27
#                   4.0         18
#                   5.0          9
# ...

# %% [markdown]
# - Calculating number of people of Age_bin = 1 and 8 from each Pclass.

# %%
#From Passenger Class = 1

agebin1_pclass1 = df[(df.Age_Bin == 1) & (df.Pclass == 1)]['Pclass'].count()
agebin2_pclass1 = df[(df.Age_Bin == 2) & (df.Pclass == 1)]['Pclass'].count()
agebin3_pclass1 = df[(df.Age_Bin == 3) & (df.Pclass == 1)]['Pclass'].count()
agebin4_pclass1 = df[(df.Age_Bin == 4) & (df.Pclass == 1)]['Pclass'].count()
agebin5_pclass1 = df[(df.Age_Bin == 5) & (df.Pclass == 1)]['Pclass'].count()
agebin6_pclass1 = df[(df.Age_Bin == 6) & (df.Pclass == 1)]['Pclass'].count()
agebin7_pclass1 = df[(df.Age_Bin == 7) & (df.Pclass == 1)]['Pclass'].count()
agebin8_pclass1 = df[(df.Age_Bin == 8) & (df.Pclass == 1)]['Pclass'].count()


#From Passenger Class = 2

agebin1_pclass2 = df[(df.Age_Bin == 1) & (df.Pclass == 2)]['Pclass'].count()
agebin2_pclass2 = df[(df.Age_Bin == 2) & (df.Pclass == 2)]['Pclass'].count()
agebin3_pclass2 = df[(df.Age_Bin == 3) & (df.Pclass == 2)]['Pclass'].count()
agebin4_pclass2 = df[(df.Age_Bin == 4) & (df.Pclass == 2)]['Pclass'].count()
agebin5_pclass2 = df[(df.Age_Bin == 5) & (df.Pclass == 2)]['Pclass'].count()
agebin6_pclass2 = df[(df.Age_Bin == 6) & (df.Pclass == 2)]['Pclass'].count()
agebin7_pclass2 = df[(df.Age_Bin == 7) & (df.Pclass == 2)]['Pclass'].count()
agebin8_pclass2 = df[(df.Age_Bin == 8) & (df.Pclass == 2)]['Pclass'].count()

#From Passenger Class = 3

agebin1_pclass3 = df[(df.Age_Bin == 1) & (df.Pclass == 2)]['Pclass'].count()
agebin2_pclass3 = df[(df.Age_Bin == 2) & (df.Pclass == 2)]['Pclass'].count()
agebin3_pclass3 = df[(df.Age_Bin == 3) & (df.Pclass == 2)]['Pclass'].count()
agebin4_pclass3 = df[(df.Age_Bin == 4) & (df.Pclass == 2)]['Pclass'].count()
agebin5_pclass3 = df[(df.Age_Bin == 5) & (df.Pclass == 2)]['Pclass'].count()
agebin6_pclass3 = df[(df.Age_Bin == 6) & (df.Pclass == 2)]['Pclass'].count()
agebin7_pclass3 = df[(df.Age_Bin == 7) & (df.Pclass == 2)]['Pclass'].count()
agebin8_pclass3 = df[(df.Age_Bin == 8) & (df.Pclass == 2)]['Pclass'].count()


print('From Passenger Class = 1')
print('Number of Passengers in ship from age category =  0-10 are: ',agebin1_pclass1 )
print('Number of Passengers in ship from age category = 11-20 are: ',agebin2_pclass1 )
print('Number of Passengers in ship from age category = 21-30 are: ',agebin3_pclass1 )
print('Number of Passengers in ship from age category = 31-40 are: ',agebin4_pclass1 )
print('Number of Passengers in ship from age category = 41-50 are: ',agebin5_pclass1 )
print('Number of Passengers in ship from age category = 51-60 are: ',agebin6_pclass1 )
print('Number of Passengers in ship from age category = 61-70 are: ',agebin7_pclass1 )
print('Number of Passengers in ship from age category = 71-80 are: ',agebin8_pclass1 )

print('\nFrom Passenger Class = 2')
print('Number of Passengers in ship from age category =  0-10 are: ',agebin1_pclass2 )
print('Number of Passengers in ship from age category = 11-20 are: ',agebin2_pclass2 )
print('Number of Passengers in ship from age category = 21-30 are: ',agebin3_pclass2 )
print('Number of Passengers in ship from age category = 31-40 are: ',agebin4_pclass2 )
print('Number of Passengers in ship from age category = 41-50 are: ',agebin5_pclass2 )
print('Number of Passengers in ship from age category = 51-60 are: ',agebin6_pclass2 )
print('Number of Passengers in ship from age category = 61-70 are: ',agebin7_pclass2 )
print('Number of Passengers in ship from age category = 71-80 are: ',agebin8_pclass2 )

print('\nFrom Passenger Class = 3')
print('Number of Passengers in ship from age category =  0-10 are: ',agebin1_pclass3 )
print('Number of Passengers in ship from age category = 11-20 are: ',agebin2_pclass3 )
print('Number of Passengers in ship from age category = 21-30 are: ',agebin3_pclass3 )
print('Number of Passengers in ship from age category = 31-40 are: ',agebin4_pclass3 )
print('Number of Passengers in ship from age category = 41-50 are: ',agebin5_pclass3 )
print('Number of Passengers in ship from age category = 51-60 are: ',agebin6_pclass3 )
print('Number of Passengers in ship from age category = 61-70 are: ',agebin7_pclass3 )
print('Number of Passengers in ship from age category = 71-80 are: ',agebin8_pclass3 )
# Out:
# From Passenger Class = 1
# Number of Passengers in ship from age category =  0-10 are:  3
# Number of Passengers in ship from age category = 11-20 are:  18
# Number of Passengers in ship from age category = 21-30 are:  65
# Number of Passengers in ship from age category = 31-40 are:  49
# Number of Passengers in ship from age category = 41-50 are:  37
# Number of Passengers in ship from age category = 51-60 are:  25
# Number of Passengers in ship from age category = 61-70 are:  10
# Number of Passengers in ship from age category = 71-80 are:  3
#
# From Passenger Class = 2
# Number of Passengers in ship from age category =  0-10 are:  16
# Number of Passengers in ship from age category = 11-20 are:  17
# Number of Passengers in ship from age category = 21-30 are:  58
# Number of Passengers in ship from age category = 31-40 are:  39
# Number of Passengers in ship from age category = 41-50 are:  18
# Number of Passengers in ship from age category = 51-60 are:  12
# ...

# %% [markdown]
# - Among children of __age 0-10 yrs__ we dont have enough data points(3) in Pclass 1, therefore __discarding it__ (blue line of Age_bin 1)<br/>
# - Also number of passengers belonging to age group __70-80 yrs__, is very less, therefore __ignoring them.__<br/>
# - In __each Pclass__, we can see that the probability of survivying of __small children(Age = 0-10 yrs)__ is _higher_ than rest age group.<br/>
# - In every Age_bin(ignoring Pclass 1 of first, and last Age_bin), __survival probability is highest for Pclass 1 and lowest for Pclass 3.__

# %%
sns.catplot(x= 'Age_Bin', y='Survived',kind='point',data=df)
plt.title('Survived Passenger according to Age Bin')
plt.show()

# %%
sns.catplot(x='Age_Bin', y='Survived',kind='point',hue='GenderClass',data=df)
plt.title('Survived passengers according to Age_Bin & GenderClass')
plt.show()

# %% [markdown]
# Its clear from the above graph that among people of all the ages, __females__ in general have __higher probability of survival than males__.

# %%
sns.catplot(x='Age_Bin',y='Survived', col='Pclass', row='GenderClass', kind='point',data=df)
plt.show()

# %% [markdown]
# From the factor plot:<br/>
#
# - In general for males, as __Pclass increases, survival probability decreases.__
# - For the rest of the females, as _Pclass increases_, _survival probability decreases._<br/>
# - You can also see survival rate within each Pclass for males and females.

# %% [markdown]
# ### 4.8 Analysing survival rate with FamilySize.

# %% [markdown]
# - Using __factorplot__ to know the survival rate on the basis of __FamilySize__.

# %%
ax= sns.catplot(x='FamilySize', y='Survived', data=df, kind='violin', aspect=1.5, palette='Greens')
ax.set(ylabel="Percent of Passengers")
plt.title('Survival by Total Family Size')
# Out:
# <ipython-input-78-1130b48078c8>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.catplot(x='FamilySize', y='Survived', data=df, kind='violin', aspect=1.5, palette='Greens')
# Text(0.5, 1.0, 'Survival by Total Family Size')

# %% [markdown]
# As __size of family increases__ its chances of survival also __increases__.

# %% [markdown]
# ### 4.9 Segment fare in bins of size 12.

# %% [markdown]
# - Using Distplot to see the distribution of __Fare__.

# %%
sns.distplot(df['Fare'], color='g')
plt.title('Distribution of Fare')
plt.show()
# Out:
# <ipython-input-79-ccd17ec1b0e2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'], color='g')

# %% [markdown]
# We have seen that __'Fare'__ mostly varies between __10 and 90.__ We will use this information to create bins.

# %% [markdown]
# - Creating a new column named __'Fare_bin'__ based on 12 interval ranges in 'Fare' as __12 bins.__

# %%
for i in range(8,0,-1):
    df.loc[df['Fare']<=i*10, 'Fare_bin']=i
df.loc[df['Fare']>80, 'Fare_bin']=9

df.head(1)
# Out:
#    Survived  Pclass   Age  SibSp  Parch  Fare Embarked GenderClass  \
# 0         0       3  22.0      1      0  7.25        S        male
#
#    FamilySize  Age_Bin  Fare_bin
# 0           2      3.0       1.0

# %%
df[['Fare','Fare_bin']].groupby('Fare_bin')['Fare'].count()
# Out:
# Fare_bin
# 1.0    249
# 2.0    167
# 3.0    134
# 4.0     57
# 5.0     16
# 6.0     35
# 7.0     11
# 8.0     31
# 9.0     74
# Name: Fare, dtype: int64

# %%
sns.distplot(df['Fare_bin'], color='g')
plt.title('Distribution of Fare Bin')
plt.show()
# Out:
# <ipython-input-82-338229cb7b12>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare_bin'], color='g')

# %%
print('The mean of the Fare is: ', df['Fare'].mean())
print('The median of the Fare is: ', df['Fare'].median())
# Out:
# The mean of the Fare is:  35.05794586563308
# The median of the Fare is:  15.9

# %% [markdown]
# - Using __barrplot__ to plot the relationship between __survival rate and Fare_bin and Pclass.__

# %%
fig, ax = plt.subplots()
sns.barplot(x='Fare_bin', y='Survived', hue='Pclass', data=df, ax=ax)
plt.title('Relationship between Survival Rate with Fare Bin & Pclass')
plt.show()

# %% [markdown]
# - As __fare increases, survival chances also increases__.
# - Also __Pclass 1__ (blue color) have __more chances to survive__ compared to other Pclass.

# %% [markdown]
# ### 4.10 Draw pair plot to know the joint relationship between 'Fare','Age','Pclass' and 'Survived'

# %%
sns.pairplot(df[['Fare','Age','Pclass','Survived']], hue='Survived', dropna=True, markers=['o','s'])
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# Observing the diagonal elements,
# - More people of Pclass 1 survived than died (First peak of red is higher than blue)
# - More people of Pclass 3 died than survived (Third peak of blue is higher than red)
# - More people of age group 20-40 died than survived.
# - Most of the people paying less fare died.

# %% [markdown]
# ### 4.12 Hypothesis: Women and children are more likely to survive

# %% [markdown]
# On studying Questionnaire 4.1, 4.2 and 4.3 we observed that an overwhelming percentage of __women & children__ have survived the titanic clash.
# - __76%__ of __females__ survived.
# - __57%__ of __children__ also survived.
# - Only __16%__ of __males__ survived.<br/>
# Also the survival rate for male is very low irrespective of the _class_ he belongs to and the _survival rate is less_ for all the _3rd class passengers._ Almost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 died.

# %% [markdown]
# ## 5. Conclusion
#
# - With the help of this notebook we learnt how exploratory data analysis can be carried out using Pandas plotting.
# - Also we have seen making use of packages like __matplotlib and seaborn__ to develop better insights about the data.<br/>
# - We have also seen how __preproceesing__ helps in dealing with _missing_ values and irregualities present in the data. We also learnt how to _create new features_ which will in turn help us to better predict the survival.
# - We also make use of __pandas profiling__ feature to generate an html report containing all the information of the various features present in the dataset.
# - We have seen the impact of columns like _Age, Embarked, Fare, SibSp and Parch_ on the rate of survival.
# - The most important inference drawn from all this analysis is, we get to know what are the __features on which survival is highly positively and negatively coorelated with.__
# - This analysis will help us to choose which __machine learning model__ we can apply to predict survival of test dataset.
